# %% [markdown]
# ## Read in data

# %% [markdown]
# As this segment of the analysis focuses on Classification Algorithms, the cleaned dataset containing reduced columns is considered for model efficiency. The county names are retrieved from the initial data.

# %%
import pandas as pd

# %%
data3 = pd.read_csv('complete_data.csv', index_col=0, low_memory=False)
data3.head(3)
# Out:
#             area       county area_code pension Long_Dist_Income  \
# 0   Carlow Urban   Co. Carlow       001    15.8            35617
# 1  Graigue Urban   Co. Carlow       002    20.4            31854
# 2       Clonmore   Co. Carlow       003    17.0            43499
#
#    gross_income short_dist_income Social Welfare  \
# 0        105943           22520.0           29.4
# 1        101740           21180.0           26.3
# 2         96130           25389.0           12.1
#
#   Agriculture, Forestry and Fishing (A) (%) Construction (F) (%)  ...  \
# 0                                       1.1                  5.0  ...
# 1                                       2.0                  8.3  ...
# 2                                      10.6                  8.9  ...
#
#   T1_1AGE45_49F T1_1AGE50_54F T1_1AGE55_59F  T1_1AGE60_64F  T1_1AGE65_69F  \
# 0           133           125           106            100            102
# 1            50            43            43             32             31
# 2            21            21            22             13              8
#
#   T1_1AGE70_74F T1_1AGE75_79F T1_1AGE80_84F  T1_1AGEGE_85F  T1_1AGETF
# 0            84            92            55             59      2,195
# 1            30            19            33             17        694
# 2             5            12             6              5        268
#
# [3 rows x 785 columns]

# %%
gi = data3[['gross_income']]
gi.head(3)
# Out:
#    gross_income
# 0        105943
# 1        101740
# 2         96130

# %%
county = data3[['county']]
county.head(3)
# Out:
#         county
# 0   Co. Carlow
# 1   Co. Carlow
# 2   Co. Carlow

# %%
data2 = pd.read_csv('Cleaned__complete_data.csv', index_col=0)
data2.head(3)
# Out:
#    pension  Long_Dist_Income  Agriculture, Forestry and Fishing (A) (%)  \
# 0     15.8           35617.0                                        1.1
# 1     20.4           31854.0                                        2.0
# 2     17.0           43499.0                                       10.6
#
#    Construction (F) (%)  \
# 0                   5.0
# 1                   8.3
# 2                   8.9
#
#    Financial, Real Estate, Administrative and Services (K,L,N,S) (%)  \
# 0                                               14.0
# 1                                               16.2
# 2                                               13.3
#
#    Industry (B,C,D,E) (%)  Public Service, Education and Health (O,P,Q) (%)  \
# 0                    12.6                                              30.9
# 1                    12.7                                              25.7
# 2                    13.9                                              27.3
#
#    Wholesale, Transport and Accomodation (G,H,I) (%)  T1_1AGE0T  T6_1_CM_H  \
# 0                                               25.3         43          1
# 1                                               26.9         16          1
# 2                                               13.7          8          1
#
#    T6_5_PCH  T6_6_GSLA  T6_6_OP  T6_7_OTH  T6_8_UHH  T8_1_OTHM  T9_2_HJ  \
# 0        13         31        4         4       1.0         12        3
# 1         4          9        0         3       7.0          3        3
# 2         1          2      157         2       9.0          2        2
#
#    gross_income
# 0        105943
# 1        101740
# 2         96130

# %% [markdown]
# ## Get classification data

# %%
data2.dtypes.unique()
# Out:
# array([dtype('float64'), dtype('int64')], dtype=object)

# %% [markdown]
# Select all non-numeric data

# %%
data = data3.select_dtypes('O')
data.head(3)
# Out:
#             area       county area_code pension Long_Dist_Income  \
# 0   Carlow Urban   Co. Carlow       001    15.8            35617
# 1  Graigue Urban   Co. Carlow       002    20.4            31854
# 2       Clonmore   Co. Carlow       003    17.0            43499
#
#   short_dist_income Social Welfare Agriculture, Forestry and Fishing (A) (%)  \
# 0           22520.0           29.4                                       1.1
# 1           21180.0           26.3                                       2.0
# 2           25389.0           12.1                                      10.6
#
#   Construction (F) (%)  \
# 0                  5.0
# 1                  8.3
# 2                  8.9
#
#   Financial, Real Estate, Administrative and Services (K,L,N,S) (%)  ...  \
# 0                                               14.0                 ...
# 1                                               16.2                 ...
# 2                                               13.3                 ...
#
#   T1_1AGE40_44M T1_1AGE45_49M T1_1AGETM T1_1AGE20_24F T1_1AGE25_29F  \
# 0           167           145     2,365           255           201
# 1            38            36       711            45            94
# 2            20            16       258            11            14
#
#   T1_1AGE30_34F T1_1AGE35_39F T1_1AGE40_44F T1_1AGE45_49F T1_1AGETF
# 0           165           152           125           133     2,195
# 1            54            46            30            50       694
# 2            18            17            17            21       268
#
# [3 rows x 478 columns]

# %%
data.dtypes.unique()
# Out:
# array([dtype('O')], dtype=object)

# %% [markdown]
# The areas of interest are the area descriptions

# %%
data = data[['area', 'county', 'GUID', 'GEOGID', 'GEOGDESC']]
data.head(3)
# Out:
#             area       county                              GUID        GEOGID  \
# 0   Carlow Urban   Co. Carlow  2AE19629185813A3E055000000000001  ED3409_01001
# 1  Graigue Urban   Co. Carlow  2AE196291A5913A3E055000000000001  ED3409_01002
# 2       Clonmore   Co. Carlow  2AE19629186413A3E055000000000001  ED3409_01003
#
#         GEOGDESC
# 0   Carlow Urban
# 1  Graigue Urban
# 2       Clonmore

# %% [markdown]
# Add target variable to dataset

# %%
data.insert(5, 'gross_income', gi, allow_duplicates = False)
data.head(3)
# Out:
#             area       county                              GUID        GEOGID  \
# 0   Carlow Urban   Co. Carlow  2AE19629185813A3E055000000000001  ED3409_01001
# 1  Graigue Urban   Co. Carlow  2AE196291A5913A3E055000000000001  ED3409_01002
# 2       Clonmore   Co. Carlow  2AE19629186413A3E055000000000001  ED3409_01003
#
#         GEOGDESC  gross_income
# 0   Carlow Urban        105943
# 1  Graigue Urban        101740
# 2       Clonmore         96130

# %% [markdown]
# Area and GEODESC columns look similar. They are checked to see if they are identical.

# %%
data['area'].equals(data['GEOGDESC'])
# Out:
# False

# %%
data.query('area != GEOGDESC')
# Out:
#                                           area            county  \
# 0                                 Carlow Urban        Co. Carlow
# 11                  Ballinacarrig (Part Urban)        Co. Carlow
# 18                   Carlow Rural (Part Urban)         Co Carlow
# 379                    Athy Rural (Part Rural)       Co. Kildare
# 724                Longford Rural (Part Urban)      Co. Longford
# 751                    Castletown (Part Urban)         Co. Louth
# 755                 Dundalk Rural (Part Urban)         Co. Louth
# 758                  Haggardstown (Part Urban)         Co. Louth
# 769                   St. Peter's (Part Urban)         Co. Louth
# 797   Ceannanus Mór (Kells) Rural (Part Urban)         Co. Meath
# 826                   Navan Rural (Part Urban)         Co. Meath
# 863                    Trim Rural (Part Urban)         Co. Meath
# 952            Athlone East Rural (Part Urban)     Co. Westmeath
# 963                       Moydrum (Part Urban)     Co. Westmeath
# 1075            Enniscorthy Rural (Part Urban)       Co. Wexford
# 1177                Wexford Rural (Part Urban)       Co. Wexford
# 1213                  Kilmacanoge (Part Urban)       Co. Wicklow
# 1284                   Clareabbey (Part Urban)         Co. Clare
# 1287                        Doora (Part Urban)         Co. Clare
# 1290                  Ennis Rural (Part Urban)         Co. Clare
# 1300                  Spancelhill (Part Urban)         Co. Clare
# 1809                Youghal Rural (Part Rural)          Co. Cork
# 1889              Killarney Rural (Part Urban)         Co. Kerry
# 1897                     Muckross (Part Urban)         Co. Kerry
# 1945                 Blennerville (Part Urban)         Co. Kerry
# 1972                 Tralee Rural (Part Urban)         Co. Kerry
# 2183                                 / Lackagh               NaN
# 2278                Clonmel Rural (Part Urban)   South Tipperary
# 2279                Inishlounaght (Part Urban)   South Tipperary
# 2452                       Baile an Bhriotaigh       Galway City
# 2765               Ardnaree North (Part Urban)          Co. Mayo
# 2766         Ardnaree South Rural (Part Urban)          Co. Mayo
# 2769                Ballina Rural (Part Urban)          Co. Mayo
# 2832              Castlebar Rural (Part Urban)          Co. Mayo
# 2901                     Kilmeena (Part Urban)          Co. Mayo
# 3285                  Ballymacool (Part Rural)       Co. Donegal
# 3286                   Castlewray (Part Rural)       Co. Donegal
# 3288                   Corravaddy (Part Rural)       Co. Donegal
# 3289                  Edenacarnan (Part Rural)       Co. Donegal
# 3294            Letterkenny Rural (Part Rural)       Co. Donegal
# 3295                   Magheraboy (Part Rural)       Co. Donegal
# 3365          Castleblayney Rural (Part Rural)      Co. Monaghan
# 3374                 Clones Rural (Part Rural)      Co. Monaghan
# 3401               Monaghan Rural (Part Rural)      Co. Monaghan
#
#                                   GUID              GEOGID  \
# 0     2AE19629185813A3E055000000000001        ED3409_01001
# 11    2AE19629183713A3E055000000000001        ED3409_01012
# 18    2AE19629185713A3E055000000000001        ED3409_01019
# 379   2AE19629223B13A3E055000000000001        ED3409_06004
# 724   2AE19629192713A3E055000000000001        ED3409_09051
# 751   2AE19629196913A3E055000000000001        ED3409_10023
# 755   2AE1962918E213A3E055000000000001        ED3409_10027
# 758   2AE1962918F913A3E055000000000001        ED3409_10030
# 769   2AE19629192A13A3E055000000000001        ED3409_10041
# 797   2AE1962918BE13A3E055000000000001        ED3409_11026
# 826   2AE19629189213A3E055000000000001        ED3409_11055
# 863   2AE19629182B13A3E055000000000001        ED3409_11092
# 952   2AE196291BCC13A3E055000000000001        ED3409_13003
# 963   2AE196291B3513A3E055000000000001        ED3409_13014
# 1075  2AE196291EB713A3E055000000000001        ED3409_14021
# 1177  2AE196291E4513A3E055000000000001        ED3409_14123
# 1213  2AE196291E7813A3E055000000000001        ED3409_15035
# 1284  2AE19629200613A3E055000000000001        ED3409_16026
# 1287  2AE196291FD313A3E055000000000001        ED3409_16029
# 1290  2AE196291FFA13A3E055000000000001        ED3409_16032
# 1300  2AE19629201513A3E055000000000001        ED3409_16042
# 1809  2AE19629214713A3E055000000000001        ED3409_18325
# 1889  2AE19629228813A3E055000000000001        ED3409_19082
# 1897  2AE19629228913A3E055000000000001        ED3409_19090
# 1945  2AE19629232913A3E055000000000001        ED3409_19138
# 1972  2AE19629221E13A3E055000000000001        ED3409_19165
# 2183  3576C59998334152E0530100007F0280  ED3409_22037/22045
# 2278  2AE196291C7F13A3E055000000000001        ED3409_23133
# 2279  2AE196291C5F13A3E055000000000001        ED3409_23134
# 2452  2AE19629235B13A3E055000000000001        ED3409_26002
# 2765  2AE19629196013A3E055000000000001        ED3409_29006
# 2766  2AE19629196113A3E055000000000001        ED3409_29007
# 2769  2AE19629197513A3E055000000000001        ED3409_29010
# 2832  2AE19629194813A3E055000000000001        ED3409_29074
# 2901  2AE19629195B13A3E055000000000001        ED3409_29144
# 3285  2AE1962921DB13A3E055000000000001        ED3409_33096
# 3286  2AE19629208113A3E055000000000001        ED3409_33097
# 3288  2AE1962920B313A3E055000000000001        ED3409_33099
# 3289  2AE1962920F613A3E055000000000001        ED3409_33100
# 3294  2AE1962920EB13A3E055000000000001        ED3409_33105
# 3295  2AE19629204313A3E055000000000001        ED3409_33106
# 3365  2AE196291AAA13A3E055000000000001        ED3409_34027
# 3374  2AE196291AB613A3E055000000000001        ED3409_34036
# 3401  2AE196291AA113A3E055000000000001        ED3409_34063
#
#                          GEOGDESC  gross_income
# 0                    Carlow Urban        105943
# 11                  Ballinacarrig         87584
# 18                   Carlow Rural         82500
# 379                    Athy Rural         58160
# 724                Longford Rural         52682
# 751                    Castletown         52342
# 755                 Dundalk Rural         52236
# 758                  Haggardstown         52221
# 769                   St. Peter's         52091
# 797   Ceannanus Mór (Kells) Rural         51795
# 826                   Navan Rural         51545
# 863                    Trim Rural         51122
# 952            Athlone East Rural         50199
# 963                       Moydrum         50093
# 1075            Enniscorthy Rural         48919
# 1177                Wexford Rural         48037
# 1213                  Kilmacanoge         47793
# 1284                   Clareabbey         47035
# 1287                        Doora         47008
# 1290                  Ennis Rural         46971
# 1300                  Spancelhill         46882
# 1809                Youghal Rural         42697
# 1889              Killarney Rural         42101
# 1897                     Muckross         42042
# 1945                 Blennerville         41614
# 1972                 Tralee Rural         41400
# 2183          Greenhall / Lackagh         39728
# 2278                Clonmel Rural         38903
# 2279                Inishlounaght         38883
# 2452          Baile an Bhriotaihg         37464
# 2765               Ardnaree North         34415
# 2766         Ardnaree South Rural         34412
# 2769                Ballina Rural         34383
# 2832              Castlebar Rural         33814
# 2901                     Kilmeena         32997
# 3285                  Ballymacool         26528
# 3286                   Castlewray         26522
# 3288                   Corravaddy         26486
# 3289                  Edenacarnan         26485
# 3294            Letterkenny Rural         26410
# 3295                   Magheraboy         26406
# 3365          Castleblayney Rural         23763
# 3374                 Clones Rural         23473
# 3401               Monaghan Rural         18780

# %% [markdown]
# There are only a handful of recors where the two columns are not identical. And in these cases area is just a slightly more detailed metric for GEODESC. To reduce data redundancy area is dropped.

# %%
data.drop(columns=data.columns[1], axis=1, inplace=True)
data.head(3)
# Out:
#             area                              GUID        GEOGID  \
# 0   Carlow Urban  2AE19629185813A3E055000000000001  ED3409_01001
# 1  Graigue Urban  2AE196291A5913A3E055000000000001  ED3409_01002
# 2       Clonmore  2AE19629186413A3E055000000000001  ED3409_01003
#
#         GEOGDESC  gross_income
# 0   Carlow Urban        105943
# 1  Graigue Urban        101740
# 2       Clonmore         96130

# %% [markdown]
# Ensure that there are no values where the target variable is 0.

# %%
x = data['gross_income'] < 0
import numpy as np
np.where(x)[0]
# Out:
# array([], dtype=int64)

# %% [markdown]
# ##Put income into binned categories for classification

# %%
data['Binned Income'] = pd.cut(data['gross_income'], 5, labels=False)
data.head(3)
# Out:
#             area                              GUID        GEOGID  \
# 0   Carlow Urban  2AE19629185813A3E055000000000001  ED3409_01001
# 1  Graigue Urban  2AE196291A5913A3E055000000000001  ED3409_01002
# 2       Clonmore  2AE19629186413A3E055000000000001  ED3409_01003
#
#         GEOGDESC  gross_income  Binned Income
# 0   Carlow Urban        105943              4
# 1  Graigue Urban        101740              4
# 2       Clonmore         96130              4

# %% [markdown]
# Make bins more understandable

# %%
dict1 = {4: 'High', 3: 'MedHigh', 2: 'Med', 1: 'MedLow', 0: 'Low'}
data = data.replace({'Binned Income': dict1})
data.head(3)
# Out:
#             area                              GUID        GEOGID  \
# 0   Carlow Urban  2AE19629185813A3E055000000000001  ED3409_01001
# 1  Graigue Urban  2AE196291A5913A3E055000000000001  ED3409_01002
# 2       Clonmore  2AE19629186413A3E055000000000001  ED3409_01003
#
#         GEOGDESC  gross_income Binned Income
# 0   Carlow Urban        105943          High
# 1  Graigue Urban        101740          High
# 2       Clonmore         96130          High

# %% [markdown]
# Drop gross_income column as it is now represented in Binned Income

# %%
data.drop(columns=data.columns[4], axis=1, inplace=True)
data.head(3)
# Out:
#             area                              GUID        GEOGID  \
# 0   Carlow Urban  2AE19629185813A3E055000000000001  ED3409_01001
# 1  Graigue Urban  2AE196291A5913A3E055000000000001  ED3409_01002
# 2       Clonmore  2AE19629186413A3E055000000000001  ED3409_01003
#
#         GEOGDESC Binned Income
# 0   Carlow Urban          High
# 1  Graigue Urban          High
# 2       Clonmore          High

# %% [markdown]
# ##NA Check

# %%
data.isna().sum()
# Out:
# area             0
# GUID             0
# GEOGID           0
# GEOGDESC         0
# Binned Income    0
# dtype: int64

# %% [markdown]
# ##Save prepared data

# %%
data
# Out:
#                area                              GUID        GEOGID  \
# 0      Carlow Urban  2AE19629185813A3E055000000000001  ED3409_01001
# 1     Graigue Urban  2AE196291A5913A3E055000000000001  ED3409_01002
# 2          Clonmore  2AE19629186413A3E055000000000001  ED3409_01003
# 3       Hacketstown  2AE19629187F13A3E055000000000001  ED3409_01004
# 4       Haroldstown  2AE19629188713A3E055000000000001  ED3409_01005
# ...             ...                               ...           ...
# 3404    Shanmullagh  2AE196291AC213A3E055000000000001  ED3409_34066
# 3405        Sheskin  2AE196291AC313A3E055000000000001  ED3409_34067
# 3406       Tedavnet  2AE196291AC513A3E055000000000001  ED3409_34068
# 3407       Tehallan  2AE196291ACF13A3E055000000000001  ED3409_34069
# 3408    Tullycorbet  2AE196291AD013A3E055000000000001  ED3409_34070
#
#            GEOGDESC Binned Income
# 0      Carlow Urban          High
# 1     Graigue Urban          High
# 2          Clonmore          High
# 3       Hacketstown          High
# 4       Haroldstown          High
# ...             ...           ...
# 3404    Shanmullagh           Low
# 3405        Sheskin           Low
# 3406       Tedavnet           Low
# 3407       Tehallan           Low
# 3408    Tullycorbet           Low
#
# [3409 rows x 5 columns]

# %%
data.to_csv('Classification_data.csv')
